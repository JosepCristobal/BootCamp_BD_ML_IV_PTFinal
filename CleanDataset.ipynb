# %% [markdown]
# ### Machine Learning desarrollo práctica final de módulo
# V_3.2

# %%
# En primer lugar, cargamos las librerías necesarias

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %matplotlib inline 

cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

# %%
# Empezamos con la incorporación de los datos del fichero csv de Airbnb para generar nuestro dataset
# Y visualizamos los primeros elementos de forma transversal

airbnb_Data = pd.read_csv("./Data/airbnb-listings.csv", sep=";", decimal=".")
airbnb_Data.head(5).T
# Out:
#                                                                                 0  \
# ID                                                                       13994948
# Listing Url                                 https://www.airbnb.com/rooms/13994948
# Scrape ID                                                          20170402075052
# Last Scraped                                                           2017-04-02
# Name                                                       Cozy Duplex in De Pijp
# Summary                         An exceptional and quite house with all you ne...
# Space                           The house has 2 floors. In the first floor, yo...
# Description                     An exceptional and quite house with all you ne...
# Experiences Offered                                                          none
# Neighborhood Overview           De Pijp is one of the most cosmopolitan and vi...
# Notes                                                                         NaN
# Transit                         The closest tram stop to the house, Lutmanstra...
# Access                          As per stay with us, you'll be sharing all the...
# Interaction                     Usually we are working during work ours, other...
# House Rules                     * Eating inside the bedroom is not allowed. * ...
# Thumbnail Url                   https://a0.muscache.com/im/pictures/7d24d221-a...
# Medium Url                      https://a0.muscache.com/im/pictures/7d24d221-a...
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                  https://a0.muscache.com/im/pictures/7d24d221-a...
# Host ID                                                                   4742444
# Host URL                                https://www.airbnb.com/users/show/4742444
# Host Name                                                                    Javi
# Host Since                                                             2013-01-17
# Host Location                           Amsterdam, North Holland, The Netherlands
# Host About                      Javi, born in '88 in Madrid, Spain.\r\n\r\nSel...
# Host Response Time                                                 within an hour
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/pictures/b65cac92-1...
# Host Picture Url                https://a0.muscache.com/im/pictures/b65cac92-1...
# ...                                                                           ...
# Security Deposit                                                              200
# Cleaning Fee                                                                   25
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                  3
# Maximum Nights                                                                  6
# Calendar Updated                                                       6 days ago
# Has Availability                                                              NaN
# Availability 30                                                                 0
# Availability 60                                                                 2
# Availability 90                                                                 2
# Availability 365                                                                2
# Calendar last Scraped                                                  2017-04-02
# Number of Reviews                                                              12
# First Review                                                           2016-07-24
# Last Review                                                            2017-03-26
# Review Scores Rating                                                           97
# Review Scores Accuracy                                                         10
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                            10
# License                                                                       NaN
# Jurisdiction Names                                                      Amsterdam
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                  2
# Reviews per Month                                                            1.42
# Geolocation                                           52.3527003359,4.90482373061
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
#                                                                                 1  \
# ID                                                                        9474923
# Listing Url                                  https://www.airbnb.com/rooms/9474923
# Scrape ID                                                          20170512105218
# Last Scraped                                                           2017-05-12
# Name                                          Sunny&cozy flat in residential area
# Summary                         My comfortable apartment is in a quiet neighbo...
# Space                           Bright living room with open view. Newly renov...
# Description                     My comfortable apartment is in a quiet neighbo...
# Experiences Offered                                                          none
# Neighborhood Overview           The new South 'Zuid' is a trendy area with wid...
# Notes                                                                         NaN
# Transit                         Several metro, bus and tram stops on 5 minutes...
# Access                          Living room with sofa and dining table. Fully ...
# Interaction                                                                   NaN
# House Rules                     Strictly no smoking. No pets. No noise after 2...
# Thumbnail Url                                                                 NaN
# Medium Url                                                                    NaN
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                                                                NaN
# Host ID                                                                  10690074
# Host URL                               https://www.airbnb.com/users/show/10690074
# Host Name                                                                   Sofie
# Host Since                                                             2013-12-18
# Host Location                                          Antwerp, Flanders, Belgium
# Host About                      I love travelling. It's my passion. City tripp...
# Host Response Time                                                            NaN
# Host Response Rate                                                            NaN
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/10690074/prof...
# Host Picture Url                https://a0.muscache.com/im/users/10690074/prof...
# ...                                                                           ...
# Security Deposit                                                              NaN
# Cleaning Fee                                                                  NaN
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                 60
# Maximum Nights                                                               1125
# Calendar Updated                                                     7 months ago
# Has Availability                                                              NaN
# Availability 30                                                                 0
# Availability 60                                                                 3
# Availability 90                                                                33
# Availability 365                                                              308
# Calendar last Scraped                                                  2017-05-12
# Number of Reviews                                                               7
# First Review                                                           2016-01-05
# Last Review                                                            2016-07-07
# Review Scores Rating                                                           97
# Review Scores Accuracy                                                         10
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                             9
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                        strict
# Calculated host listings count                                                  1
# Reviews per Month                                                            0.43
# Geolocation                                           51.2047587311,4.40372918318
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
#                                                                                 2  \
# ID                                                                        6766647
# Listing Url                                  https://www.airbnb.com/rooms/6766647
# Scrape ID                                                          20170306202425
# Last Scraped                                                           2017-03-07
# Name                                               5 Minutes to Downtown, Zilker!
# Summary                         Get everywhere in minutes! Charming, tradition...
# Space                           Located on a large tree-covered lot less than ...
# Description                     Get everywhere in minutes! Charming, tradition...
# Experiences Offered                                                          none
# Neighborhood Overview           The Tarrytown neighborhood is best known for i...
# Notes                           Our cat normally lives in the house. He will n...
# Transit                         The location is exceptionally convenient, with...
# Access                          Outdoor porch, hammock, Weber gas grill, large...
# Interaction                     Owners or their representative will be a phone...
# House Rules                     1. Smoking is NOT allowed inside the residence...
# Thumbnail Url                   https://a0.muscache.com/im/pictures/97530293/3...
# Medium Url                      https://a0.muscache.com/im/pictures/97530293/3...
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                  https://a0.muscache.com/im/pictures/97530293/3...
# Host ID                                                                  30713291
# Host URL                               https://www.airbnb.com/users/show/30713291
# Host Name                                                                   Malia
# Host Since                                                             2015-04-06
# Host Location                                        Austin, Texas, United States
# Host About                      Malia is a native Austinite. She grew up in Ta...
# Host Response Time                                             within a few hours
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/30713291/prof...
# Host Picture Url                https://a0.muscache.com/im/users/30713291/prof...
# ...                                                                           ...
# Security Deposit                                                              NaN
# Cleaning Fee                                                                  250
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                  3
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Has Availability                                                              NaN
# Availability 30                                                                21
# Availability 60                                                                51
# Availability 90                                                                81
# Availability 365                                                              356
# Calendar last Scraped                                                  2017-03-06
# Number of Reviews                                                               1
# First Review                                                           2015-09-14
# Last Review                                                            2015-09-14
# Review Scores Rating                                                          100
# Review Scores Accuracy                                                         10
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                            10
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                        strict
# Calculated host listings count                                                  1
# Reviews per Month                                                            0.06
# Geolocation                                          30.2871239485,-97.7681636129
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
#                                                                                 3  \
# ID                                                                        5266080
# Listing Url                                  https://www.airbnb.com/rooms/5266080
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                            Habitación doble muy tranquila en centro Barce...
# Summary                         Habitación de matrimonio, estupendamente ubica...
# Space                           Es tranquilo y bien situado,  al estar orienta...
# Description                     Habitación de matrimonio, estupendamente ubica...
# Experiences Offered                                                          none
# Neighborhood Overview           Mi barrio me encanta, porque no es bullicioso ...
# Notes                                                                         NaN
# Transit                         La zona está muy bien comunicada por transport...
# Access                          No tengo inconveniente en compartir con ellos ...
# Interaction                     Suelo relacionarme con mis huéspedes todo lo q...
# House Rules                     El comportamiento que espero de mis huéspedes ...
# Thumbnail Url                                                                 NaN
# Medium Url                                                                    NaN
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                                                                NaN
# Host ID                                                                  27256558
# Host URL                               https://www.airbnb.com/users/show/27256558
# Host Name                                                           María Dolores
# Host Since                                                             2015-02-05
# Host Location                                         Barcelona, Catalonia, Spain
# Host About                      Procedo de Madrid, pero llevo dos tercios de m...
# Host Response Time                                             within a few hours
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/pictures/897cf59d-2...
# Host Picture Url                https://a0.muscache.com/im/pictures/897cf59d-2...
# ...                                                                           ...
# Security Deposit                                                              NaN
# Cleaning Fee                                                                    5
# Guests Included                                                                 1
# Extra People                                                                   15
# Minimum Nights                                                                  1
# Maximum Nights                                                               1125
# Calendar Updated                                                       2 days ago
# Has Availability                                                              NaN
# Availability 30                                                                30
# Availability 60                                                                60
# Availability 90                                                                90
# Availability 365                                                              365
# Calendar last Scraped                                                  2017-04-07
# Number of Reviews                                                               0
# First Review                                                                  NaN
# Last Review                                                                   NaN
# Review Scores Rating                                                          NaN
# Review Scores Accuracy                                                        NaN
# Review Scores Cleanliness                                                     NaN
# Review Scores Checkin                                                         NaN
# Review Scores Communication                                                   NaN
# Review Scores Location                                                        NaN
# Review Scores Value                                                           NaN
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                  2
# Reviews per Month                                                             NaN
# Geolocation                                            41.3947108065,2.1875425126
# Features                        Host Has Profile Pic,Is Location Exact,Require...
#
#                                                                                 4
# ID                                                                        2476666
# Listing Url                                  https://www.airbnb.com/rooms/2476666
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                                                          thesuites BARCELONA
# Summary                         A modernist building from the late nineteenth ...
# Space                           A modernist building from the late nineteenth ...
# Description                     A modernist building from the late nineteenth ...
# Experiences Offered                                                          none
# Neighborhood Overview           The building is located in Central Barcelona, ...
# Notes                                                                 HUTB-009034
# Transit                         Railway: Sabadell Line (stop Muntaner) Reina E...
# Access                          · Kitchen equipped with electrical appliances ...
# Interaction                                                24 hours Guest Service
# House Rules                     * For minimum stays of 7 you will have one fre...
# Thumbnail Url                   https://a0.muscache.com/im/pictures/32796765/d...
# Medium Url                      https://a0.muscache.com/im/pictures/32796765/d...
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                  https://a0.muscache.com/im/pictures/32796765/d...
# Host ID                                                                   1838761
# Host URL                                https://www.airbnb.com/users/show/1838761
# Host Name                                                                    Paul
# Host Since                                                             2012-03-01
# Host Location                                         Barcelona, Catalonia, Spain
# Host About                      Hola, me llamo Paul y nací en la ciudad de Las...
# Host Response Time                                                 within an hour
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/pictures/998e2c26-4...
# Host Picture Url                https://a0.muscache.com/im/pictures/998e2c26-4...
# ...                                                                           ...
# Security Deposit                                                              300
# Cleaning Fee                                                                   20
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                       5 days ago
# Has Availability                                                              NaN
# Availability 30                                                                 0
# Availability 60                                                                12
# Availability 90                                                                39
# Availability 365                                                              314
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                              30
# First Review                                                           2015-01-27
# Last Review                                                            2016-12-07
# Review Scores Rating                                                           88
# Review Scores Accuracy                                                          9
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                             9
# License                                                               HUTB-009034
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                        strict
# Calculated host listings count                                                  5
# Reviews per Month                                                            1.12
# Geolocation                                           41.3962925967,2.14285133656
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
# [89 rows x 5 columns]

# %%
#Calculamos el número de muestras y la dimensionalidad inicial.
N, d = airbnb_Data.shape
print(f'Numero de muestras actual es de {N} y la dimensionalidad es de {d}')
# Out:
# Numero de muestras actual es de 14780 y la dimensionalidad es de 89

# %%
# Procedemos a eliminar rows que creemos no son necesarias de airbnb_train y lo mismo aplicaremos a airbnb_test.

airbnb_Data.drop(['Listing Url', 'Scrape ID', 'Last Scraped','Name','Summary','Space','Description','Experiences Offered'
                  ,'Neighborhood Overview','Notes','Transit','Access','Interaction','House Rules',
                  'Thumbnail Url','Medium Url', 'Picture Url',
                'XL Picture Url', 'Host ID', 'Host URL','Host Name','Host About','Host Thumbnail Url'
                  ,'Host Picture Url','Host Neighbourhood','Host Verifications','Street','Neighbourhood','Features',
                 'Host Location','Neighbourhood Cleansed','License','Jurisdiction Names','Host Acceptance Rate'
                 ,'Amenities','Calendar last Scraped','Calendar Updated','Host Since','State','Market'
                ,'Smart Location','Has Availability','First Review','Last Review','Weekly Price','Monthly Price',
                 'Host Response Time','Geolocation'],
                 axis=1,inplace=True)

# %%
print(f'Dimensiones del dataset de training: {airbnb_Data.shape}')
# Out:
# Dimensiones del dataset de training: (14780, 41)

# %%
airbnb_Data.head(5).T
# Out:
#                                            0                1  \
# ID                                  13994948          9474923
# Host Response Rate                       100              NaN
# Host Listings Count                        2                1
# Host Total Listings Count                  2                1
# Neighbourhood Group Cleansed             NaN              NaN
# City                               Amsterdam        Antwerpen
# Zipcode                              1074 VM             2018
# Country Code                              NL               BE
# Country                          Netherlands          Belgium
# Latitude                             52.3527          51.2048
# Longitude                            4.90482          4.40373
# Property Type                      Apartment        Apartment
# Room Type                       Private room  Entire home/apt
# Accommodates                               2                2
# Bathrooms                                  1                1
# Bedrooms                                   1                1
# Beds                                       1                1
# Bed Type                            Real Bed         Real Bed
# Square Feet                              NaN              NaN
# Price                                     80               64
# Security Deposit                         200              NaN
# Cleaning Fee                              25              NaN
# Guests Included                            1                1
# Extra People                               0                0
# Minimum Nights                             3               60
# Maximum Nights                             6             1125
# Availability 30                            0                0
# Availability 60                            2                3
# Availability 90                            2               33
# Availability 365                           2              308
# Number of Reviews                         12                7
# Review Scores Rating                      97               97
# Review Scores Accuracy                    10               10
# Review Scores Cleanliness                 10               10
# Review Scores Checkin                     10               10
# Review Scores Communication               10               10
# Review Scores Location                    10               10
# Review Scores Value                       10                9
# Cancellation Policy                 moderate           strict
# Calculated host listings count             2                1
# Reviews per Month                       1.42             0.43
#
#                                               2             3  \
# ID                                      6766647       5266080
# Host Response Rate                          100           100
# Host Listings Count                           1             2
# Host Total Listings Count                     1             2
# Neighbourhood Group Cleansed                NaN    Sant Martí
# City                                     Austin     Barcelona
# Zipcode                                   78703         08018
# Country Code                                 US            ES
# Country                           United States         Spain
# Latitude                                30.2871       41.3947
# Longitude                              -97.7682       2.18754
# Property Type                             House     Apartment
# Room Type                       Entire home/apt  Private room
# Accommodates                                  6             2
# Bathrooms                                     2             2
# Bedrooms                                      3             1
# Beds                                          3             1
# Bed Type                               Real Bed      Real Bed
# Square Feet                                 NaN           NaN
# Price                                       795            40
# Security Deposit                            NaN           NaN
# Cleaning Fee                                250             5
# Guests Included                               1             1
# Extra People                                  0            15
# Minimum Nights                                3             1
# Maximum Nights                             1125          1125
# Availability 30                              21            30
# Availability 60                              51            60
# Availability 90                              81            90
# Availability 365                            356           365
# Number of Reviews                             1             0
# Review Scores Rating                        100           NaN
# Review Scores Accuracy                       10           NaN
# Review Scores Cleanliness                    10           NaN
# Review Scores Checkin                        10           NaN
# Review Scores Communication                  10           NaN
# Review Scores Location                       10           NaN
# Review Scores Value                          10           NaN
# Cancellation Policy                      strict      flexible
# Calculated host listings count                1             2
# Reviews per Month                          0.06           NaN
#
#                                                   4
# ID                                          2476666
# Host Response Rate                              100
# Host Listings Count                              21
# Host Total Listings Count                        21
# Neighbourhood Group Cleansed    Sarrià-Sant Gervasi
# City                                      Barcelona
# Zipcode                                       08021
# Country Code                                     ES
# Country                                       Spain
# Latitude                                    41.3963
# Longitude                                   2.14285
# Property Type                             Apartment
# Room Type                           Entire home/apt
# Accommodates                                      2
# Bathrooms                                         1
# Bedrooms                                          1
# Beds                                              1
# Bed Type                                   Real Bed
# Square Feet                                     NaN
# Price                                           129
# Security Deposit                                300
# Cleaning Fee                                     20
# Guests Included                                   1
# Extra People                                      0
# Minimum Nights                                    2
# Maximum Nights                                 1125
# Availability 30                                   0
# Availability 60                                  12
# Availability 90                                  39
# Availability 365                                314
# Number of Reviews                                30
# Review Scores Rating                             88
# Review Scores Accuracy                            9
# Review Scores Cleanliness                        10
# Review Scores Checkin                            10
# Review Scores Communication                      10
# Review Scores Location                           10
# Review Scores Value                               9
# Cancellation Policy                          strict
# Calculated host listings count                    5
# Reviews per Month                              1.12

# %%
#Verificamos el nombre de de cada columna(dimensión)
feature_names = airbnb_Data.columns[0:]
feature_names
# Out:
# Index(['ID', 'Host Response Rate', 'Host Listings Count',
#        'Host Total Listings Count', 'Neighbourhood Group Cleansed', 'City',
#        'Zipcode', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Square Feet', 'Price', 'Security Deposit',
#        'Cleaning Fee', 'Guests Included', 'Extra People', 'Minimum Nights',
#        'Maximum Nights', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Number of Reviews',
#        'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'Cancellation Policy',
#        'Calculated host listings count', 'Reviews per Month'],
#       dtype='object')

# %%
# En esta celda, filtraremos las poblaciones que contengan Madrid
# El csv descargado debía contener únicamente datos pertenecientes a Madrid

#Borramos todos los valores nulo en City
airbnb_Data.dropna(subset=['City'],inplace=True)

#Cargamos el Dataset con las poblaciones que contengan Madrid no teniendo en cuenta mayúsculas y minúsculas.
airbnb_Data = airbnb_Data[airbnb_Data["City"].str.contains('Madrid', na=False, case=False) ]

#Mostramos un conteo de todos los resultados agrupados por City
airbnb_Data["City"].value_counts()
# Out:
# Madrid                                 13207
# Madrid, Comunidad de Madrid, ES           20
# madrid                                     8
# MADRID                                     2
# Aravaca (Madrid)                           1
# Comunidad de Madrid                        1
# Centro, Madrid                             1
# las matas  madrid                          1
# Chueca, Madrid                             1
# Madrid, Comunidad de Madrid, ESPANA        1
# Delicias-Madrid                            1
# Madrid, Vallecas (Fontarrón)               1
# Name: City, dtype: int64

# %%
print('Datos airbnb antes del borrado de NaN en Price: ', airbnb_Data.shape)
# Out:
# Datos airbnb antes del borrado de NaN en Price:  (13245, 41)

# %%
#Nuestro target es el precio, por lo tanto no podemos admitir registros sin precio en train
airbnb_Data.dropna(subset=['Price'],inplace=True)

# %%
print('Datos airbnb después del borrado de NaN en Price: ', airbnb_Data.shape)
# Out:
# Datos airbnb después del borrado de NaN en Price:  (13236, 41)

# %%
#Transformamos los Feets a Metros en la superficie de los pisos, pero antes deberemos tratar los nulos
airbnb_Data['Square Feet'].fillna(0, inplace = True)

#Transformamos Feets a Metros en train
airbnb_Data[['Square Feet']] = airbnb_Data[['Square Feet']].apply(lambda x: x * 0.3048 * 0.3048)

# %%
# Guardamos físicamente en disco el dataset con una primera limpieza.
airbnb_Data.to_csv('./Data/airbnb_clean.csv', sep=';', decimal='.', index=False)
